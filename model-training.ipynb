# %%
import pandas as pd
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import joblib
import boto3
from io import BytesIO
# Out:
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 1.1build1 is an invalid version and will not be supported in a future release
#   warnings.warn(
# /usr/lib/python3/dist-packages/pkg_resources/__init__.py:116: PkgResourcesDeprecationWarning: 0.1.43ubuntu1 is an invalid version and will not be supported in a future release
#   warnings.warn(

# %%
file_path = "s3://udemy-ds-lab/house_rentals.csv"
df = pd.read_csv(file_path)

# %%
df = df[df["ADS_CATEGORY_NAME"] == "Locations"]
# Per area price
df["ADS_PRICE_SQUARE"] = df["ADS_PRICE"] / df["ADS_ATTR_SQUARE"]

# Group rows into a single row by ZIPCODE, CITY, and REAL_ESTATE_TYPE
df_grouped = df.groupby(["ADS_GEO_ZIPCODE", "ADS_GEO_CITY", "ADS_ATTR_REAL_ESTATE_TYPE"])
# Aggregation summarises statistics like average, min, max and counts
# , or even applying lambda operation
df_aggregated = df_grouped.agg(COUNT_ADS=("ADS_ID", "count"), MED_PRICE=("ADS_PRICE_SQUARE", "median"))
df = df.merge(df_aggregated, on=["ADS_GEO_ZIPCODE", "ADS_GEO_CITY", "ADS_ATTR_REAL_ESTATE_TYPE"], how="inner")

df = df[
    (df["ADS_PRICE_SQUARE"] / (df["ADS_PRICE_SQUARE"] + df["MED_PRICE"]) >= 0.25) &
    (df["ADS_PRICE_SQUARE"] / (df["ADS_PRICE_SQUARE"] + df["MED_PRICE"]) < 0.75) &
    (df["ADS_PRICE_SQUARE"] < 150) &
    (df["ADS_PRICE_SQUARE"] > 0) &
    (df["ADS_ATTR_SQUARE"] >= 9) &
    (df["ADS_ATTR_SQUARE"] <= 300) &
    (df["COUNT_ADS"] >= 5)
]

# %%
def encode_attributes(df):
    
    def ADS_ATTR_FURNISHED_Encode_Python(x):
        if x == "Meublé":
            return 2
        elif x == "Non meublé":
            return 1
        else:
            return 0

    def ADS_ATTR_REAL_ESTATE_TYPE_Encode_Python(x):
        if x == "Maison":
            return 2
        elif x == "Appartement":
            return 1
        else:
            return 0

    df["ADS_ATTR_FURNISHED_NUM"] = df["ADS_ATTR_FURNISHED"].apply(ADS_ATTR_FURNISHED_Encode_Python)
    df["ADS_ATTR_REAL_ESTATE_TYPE_NUM"] = df["ADS_ATTR_REAL_ESTATE_TYPE"].apply(ADS_ATTR_REAL_ESTATE_TYPE_Encode_Python)

    # Select the final columns
    df = df[["ADS_GEO_LAT", "ADS_GEO_LNG", "ADS_ATTR_ROOMS", "ADS_ATTR_SQUARE",
                   "ADS_ATTR_REAL_ESTATE_TYPE_NUM", "ADS_ATTR_FURNISHED_NUM", "ADS_PRICE"]]

    return df

# %%
df = encode_attributes(df)
df.head()
# Out:
#    ADS_GEO_LAT  ADS_GEO_LNG  ADS_ATTR_ROOMS  ADS_ATTR_SQUARE  \
# 0     50.64416      3.08592               2               50
# 1     50.62820      3.08117               3               68
# 2     50.63334      3.04214               1               20
# 3     50.63716      3.06284               3               70
# 4     50.63716      3.06284               2               48
#
#    ADS_ATTR_REAL_ESTATE_TYPE_NUM  ADS_ATTR_FURNISHED_NUM  ADS_PRICE
# 0                              1                       2        850
# 1                              1                       1       1170
# 2                              1                       2        395
# 3                              1                       2        850
# 4                              1                       1        708

# %%
target = "ADS_PRICE"
predictors = [x for x in df.columns if x not in [target]]

# %%
def train_model(X_train, y_train,n_estimators=250):

    model = XGBRegressor(
        booster='gbtree',
        objective='reg:squarederror',
        learning_rate=0.05,
        max_depth=5,
        min_child_weight=1,
        gamma=1,
        subsample=0.75,
        colsample_bytree=0.75,
        scale_pos_weight=1,
        n_jobs=-1,
        verbosity=1,
        n_estimators=n_estimators
    )

    model.fit(X_train, y_train, eval_set=[(X_train, y_train)], verbose=True)
    return model

# %%
X_train, X_test, y_train, y_test = train_test_split(df[predictors], df[target], test_size=0.1)
xgb_model = train_model(X_train, y_train)
# Out:
# [0]	validation_0-rmse:605.95617
# [1]	validation_0-rmse:577.23892
# [2]	validation_0-rmse:550.33712
# [3]	validation_0-rmse:524.83629
# [4]	validation_0-rmse:500.65446
# [5]	validation_0-rmse:477.71842
# [6]	validation_0-rmse:456.51855
# [7]	validation_0-rmse:436.20705
# [8]	validation_0-rmse:417.20453
# [9]	validation_0-rmse:398.56055
# [10]	validation_0-rmse:381.21341
# [11]	validation_0-rmse:364.60241
# [12]	validation_0-rmse:348.79119
# [13]	validation_0-rmse:334.33763
# [14]	validation_0-rmse:320.18251
# [15]	validation_0-rmse:307.14939
# [16]	validation_0-rmse:294.59989
# [17]	validation_0-rmse:282.40871
# [18]	validation_0-rmse:270.94208
# [19]	validation_0-rmse:260.56304
# [20]	validation_0-rmse:250.88853
# [21]	validation_0-rmse:241.14214
# [22]	validation_0-rmse:232.19141
# [23]	validation_0-rmse:223.49799
# [24]	validation_0-rmse:215.17607
# [25]	validation_0-rmse:207.55444
# [26]	validation_0-rmse:200.40853
# [27]	validation_0-rmse:193.58054
# [28]	validation_0-rmse:187.19902
# [29]	validation_0-rmse:181.26946
# [30]	validation_0-rmse:175.67462
# [31]	validation_0-rmse:170.40086
# [32]	validation_0-rmse:165.62730
# [33]	validation_0-rmse:160.90617
# [34]	validation_0-rmse:156.54424
# [35]	validation_0-rmse:152.76745
# [36]	validation_0-rmse:149.30207
# [37]	validation_0-rmse:145.87961
# [38]	validation_0-rmse:142.50037
# [39]	validation_0-rmse:139.33825
# [40]	validation_0-rmse:136.32064
# [41]	validation_0-rmse:133.76741
# [42]	validation_0-rmse:131.28780
# [43]	validation_0-rmse:129.06612
# [44]	validation_0-rmse:126.69891
# [45]	validation_0-rmse:124.63409
# [46]	validation_0-rmse:122.69147
# [47]	validation_0-rmse:121.09255
# [48]	validation_0-rmse:119.32783
# [49]	validation_0-rmse:117.89337
# [50]	validation_0-rmse:116.50311
# [51]	validation_0-rmse:115.01639
# [52]	validation_0-rmse:113.81669
# [53]	validation_0-rmse:112.66669
# [54]	validation_0-rmse:111.76023
# [55]	validation_0-rmse:110.81926
# [56]	validation_0-rmse:109.65390
# [57]	validation_0-rmse:108.82986
# [58]	validation_0-rmse:108.02656
# [59]	validation_0-rmse:107.19160
# [60]	validation_0-rmse:106.29780
# [61]	validation_0-rmse:105.66973
# [62]	validation_0-rmse:105.18124
# [63]	validation_0-rmse:104.48388
# [64]	validation_0-rmse:103.85200
# [65]	validation_0-rmse:103.41130
# [66]	validation_0-rmse:102.83562
# [67]	validation_0-rmse:102.45206
# [68]	validation_0-rmse:101.94862
# [69]	validation_0-rmse:101.42793
# [70]	validation_0-rmse:100.99414
# [71]	validation_0-rmse:100.57429
# [72]	validation_0-rmse:100.21878
# [73]	validation_0-rmse:99.89051
# [74]	validation_0-rmse:99.48812
# [75]	validation_0-rmse:99.12888
# [76]	validation_0-rmse:98.80752
# [77]	validation_0-rmse:98.50131
# [78]	validation_0-rmse:98.15557
# [79]	validation_0-rmse:97.93965
# [80]	validation_0-rmse:97.68103
# [81]	validation_0-rmse:97.45591
# [82]	validation_0-rmse:97.12624
# [83]	validation_0-rmse:96.84857
# [84]	validation_0-rmse:96.62069
# [85]	validation_0-rmse:96.49357
# [86]	validation_0-rmse:96.32855
# [87]	validation_0-rmse:96.12037
# [88]	validation_0-rmse:95.93479
# [89]	validation_0-rmse:95.76061
# [90]	validation_0-rmse:95.65070
# [91]	validation_0-rmse:95.45190
# [92]	validation_0-rmse:95.27315
# [93]	validation_0-rmse:95.03600
# [94]	validation_0-rmse:94.91237
# [95]	validation_0-rmse:94.71662
# [96]	validation_0-rmse:94.53753
# [97]	validation_0-rmse:94.42624
# [98]	validation_0-rmse:94.28538
# [99]	validation_0-rmse:94.12109
# [100]	validation_0-rmse:93.99415
# [101]	validation_0-rmse:93.91777
# [102]	validation_0-rmse:93.78455
# [103]	validation_0-rmse:93.65820
# [104]	validation_0-rmse:93.53411
# [105]	validation_0-rmse:93.38899
# [106]	validation_0-rmse:93.27671
# [107]	validation_0-rmse:93.16498
# [108]	validation_0-rmse:93.05106
# [109]	validation_0-rmse:92.93744
# [110]	validation_0-rmse:92.77809
# [111]	validation_0-rmse:92.66488
# [112]	validation_0-rmse:92.57678
# [113]	validation_0-rmse:92.51025
# [114]	validation_0-rmse:92.43835
# [115]	validation_0-rmse:92.41523
# [116]	validation_0-rmse:92.34222
# [117]	validation_0-rmse:92.27857
# [118]	validation_0-rmse:92.20160
# [119]	validation_0-rmse:92.12560
# [120]	validation_0-rmse:92.06080
# [121]	validation_0-rmse:92.00337
# [122]	validation_0-rmse:91.94537
# [123]	validation_0-rmse:91.88345
# [124]	validation_0-rmse:91.76361
# [125]	validation_0-rmse:91.71074
# [126]	validation_0-rmse:91.61452
# [127]	validation_0-rmse:91.48938
# [202]	validation_0-rmse:87.88463
# [203]	validation_0-rmse:87.85251
# [204]	validation_0-rmse:87.81403
# [205]	validation_0-rmse:87.75640
# [206]	validation_0-rmse:87.71865
# [207]	validation_0-rmse:87.70927
# [208]	validation_0-rmse:87.65248
# [209]	validation_0-rmse:87.60087
# [210]	validation_0-rmse:87.56479
# [211]	validation_0-rmse:87.53929
# [212]	validation_0-rmse:87.47819
# [213]	validation_0-rmse:87.45545
# [214]	validation_0-rmse:87.41935
# [215]	validation_0-rmse:87.37802
# [216]	validation_0-rmse:87.34755
# [217]	validation_0-rmse:87.28341
# [218]	validation_0-rmse:87.21788
# [219]	validation_0-rmse:87.18837
# [220]	validation_0-rmse:87.17975
# [221]	validation_0-rmse:87.15476
# [222]	validation_0-rmse:87.13241
# [223]	validation_0-rmse:87.06567
# [224]	validation_0-rmse:87.05159
# [225]	validation_0-rmse:87.03106
# [226]	validation_0-rmse:87.00507
# [227]	validation_0-rmse:86.96909
# [228]	validation_0-rmse:86.91115
# [229]	validation_0-rmse:86.89349
# [230]	validation_0-rmse:86.81382
# [231]	validation_0-rmse:86.78161
# [232]	validation_0-rmse:86.69671
# [233]	validation_0-rmse:86.66819
# [234]	validation_0-rmse:86.61599
# [235]	validation_0-rmse:86.58862
# [236]	validation_0-rmse:86.57583
# [237]	validation_0-rmse:86.55106
# [238]	validation_0-rmse:86.48549
# [239]	validation_0-rmse:86.43371
# [240]	validation_0-rmse:86.41723
# [241]	validation_0-rmse:86.38100
# [242]	validation_0-rmse:86.33313
# [243]	validation_0-rmse:86.30552
# [244]	validation_0-rmse:86.27771
# [245]	validation_0-rmse:86.22295
# [246]	validation_0-rmse:86.20803
# [247]	validation_0-rmse:86.17080
# [248]	validation_0-rmse:86.14354
# [249]	validation_0-rmse:86.10191

# %%
predictions = xgb_model.predict(X_test)
r2_score(y_test, predictions)
# Out:
# 0.8246515672767909

# %%
bucket_name = "udemy-ds-lab"
file_key = "model-artifact/house_rentability.joblib"

buffer = BytesIO()
joblib.dump(xgb_model, buffer)
s3 = boto3.client('s3')
s3.put_object(Bucket=bucket_name, Key=file_key, Body=buffer.getvalue())
# Out:
# {'ResponseMetadata': {'RequestId': '5VF0MGEZ3YJMBSWR',
#   'HostId': 'N+9R/SOHbLck960RicQaeO0wyKLSUkB5slEl0H0bQ+s4n2oYvMYnx1Wuxpk6V+uA7gapGc5HAyE=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'N+9R/SOHbLck960RicQaeO0wyKLSUkB5slEl0H0bQ+s4n2oYvMYnx1Wuxpk6V+uA7gapGc5HAyE=',
#    'x-amz-request-id': '5VF0MGEZ3YJMBSWR',
#    'date': 'Tue, 03 Oct 2023 13:25:50 GMT',
#    'x-amz-server-side-encryption': 'AES256',
#    'etag': '"fc09b4c36bdc62aebc2e7f3552d969dc"',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'ETag': '"fc09b4c36bdc62aebc2e7f3552d969dc"',
#  'ServerSideEncryption': 'AES256'}
